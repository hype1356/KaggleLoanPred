# %%
# imports
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
import xgboost as xgb

# %%
# read in training data
xtrain = pd.read_csv('data/train.csv')
ytrain = xtrain['loan_status']
xtrain = xtrain.drop(['id', 'loan_status'], axis=1)
xtrain['person_home_ownership'] = xtrain['person_home_ownership'].map({'RENT': 0, 'MORTGAGE': 1, 'OWN': 2, 'OTHER': 3})
xtrain['loan_intent'] = xtrain['loan_intent'].map({'PERSONAL': 0, 'EDUCATION': 1, 'MEDICAL': 2, 'VENTURE': 3, 'HOME': 4})
xtrain['loan_grade'] = xtrain['loan_grade'].map({'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5})
xtrain['cb_person_default_on_file'] = xtrain['cb_person_default_on_file'].map({'Y': 1, 'N': 0})

# split data into training and validation sets
xtrain, xval, ytrain, yval = train_test_split(xtrain, ytrain, test_size=0.1, random_state=0)

# %%
# create and train model
param_grid = {
    'objective': ['binary:logistic'],
    'device': ['gpu'],
    'max_depth': [6, 5],
    'eta': [0.1],
    'subsample': [1],
    'colsample_bytree': [1]
}

xgb_model = xgb.XGBClassifier()  # Or XGBRegressor for regression
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, scoring='accuracy', cv=5, verbose=10)
grid_search.fit(xtrain, ytrain)

print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_) 

params = {
    'objective': 'binary:logistic',
    'device': 'gpu',
    'max_depth': 5,
    'eta': 0.1,
    'subsample': 1,
    'colsample_bytree': 1
}

num_round = 1000
watchlist = [(xgb.DMatrix(xtrain, ytrain), 'train'), (xgb.DMatrix(xval, yval), 'eval')]

model = xgb.train(params, xgb.DMatrix(xtrain, ytrain), num_round, watchlist, early_stopping_rounds=10)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START colsample_bytree=1, device=gpu, eta=0.1, max_depth=6, objective=binary:logistic, subsample=1
# [CV 1/5; 1/2] END colsample_bytree=1, device=gpu, eta=0.1, max_depth=6, objective=binary:logistic, subsample=1;, score=0.949 total time=   0.5s
# [CV 2/5; 1/2] START colsample_bytree=1, device=gpu, eta=0.1, max_depth=6, objective=binary:logistic, subsample=1
# [CV 2/5; 1/2] END colsample_bytree=1, device=gpu, eta=0.1, max_depth=6, objective=binary:logistic, subsample=1;, score=0.947 total time=   0.3s
# [CV 3/5; 1/2] START colsample_bytree=1, device=gpu, eta=0.1, max_depth=6, objective=binary:logistic, subsample=1
# [CV 3/5; 1/2] END colsample_bytree=1, device=gpu, eta=0.1, max_depth=6, objective=binary:logistic, subsample=1;, score=0.942 total time=   0.3s
# [CV 4/5; 1/2] START colsample_bytree=1, device=gpu, eta=0.1, max_depth=6, objective=binary:logistic, subsample=1
# [CV 4/5; 1/2] END colsample_bytree=1, device=gpu, eta=0.1, max_depth=6, objective=binary:logistic, subsample=1;, score=0.949 total time=   0.3s
# [CV 5/5; 1/2] START colsample_bytree=1, device=gpu, eta=0.1, max_depth=6, objective=binary:logistic, subsample=1
# [CV 5/5; 1/2] END colsample_bytree=1, device=gpu, eta=0.1, max_depth=6, objective=binary:logistic, subsample=1;, score=0.946 total time=   0.3s
# [CV 1/5; 2/2] START colsample_bytree=1, device=gpu, eta=0.1, max_depth=5, objective=binary:logistic, subsample=1
# [CV 1/5; 2/2] END colsample_bytree=1, device=gpu, eta=0.1, max_depth=5, objective=binary:logistic, subsample=1;, score=0.949 total time=   0.2s
# [CV 2/5; 2/2] START colsample_bytree=1, device=gpu, eta=0.1, max_depth=5, objective=binary:logistic, subsample=1
# [CV 2/5; 2/2] END colsample_bytree=1, device=gpu, eta=0.1, max_depth=5, objective=binary:logistic, subsample=1;, score=0.947 total time=   0.2s
# [CV 3/5; 2/2] START colsample_bytree=1, device=gpu, eta=0.1, max_depth=5, objective=binary:logistic, subsample=1
# [CV 3/5; 2/2] END colsample_bytree=1, device=gpu, eta=0.1, max_depth=5, objective=binary:logistic, subsample=1;, score=0.943 total time=   0.2s
# [CV 4/5; 2/2] START colsample_bytree=1, device=gpu, eta=0.1, max_depth=5, objective=binary:logistic, subsample=1
# [CV 4/5; 2/2] END colsample_bytree=1, device=gpu, eta=0.1, max_depth=5, objective=binary:logistic, subsample=1;, score=0.949 total time=   0.3s
# [CV 5/5; 2/2] START colsample_bytree=1, device=gpu, eta=0.1, max_depth=5, objective=binary:logistic, subsample=1
# [CV 5/5; 2/2] END colsample_bytree=1, device=gpu, eta=0.1, max_depth=5, objective=binary:logistic, subsample=1;, score=0.946 total time=   0.2s
# Best parameters: {'colsample_bytree': 1, 'device': 'gpu', 'eta': 0.1, 'max_depth': 5, 'objective': 'binary:logistic', 'subsample': 1}
# Best score: 0.9470116412851997
# [0]	train-logloss:0.37274	eval-logloss:0.37308
# [1]	train-logloss:0.34168	eval-logloss:0.34175
# [152]	train-logloss:0.13925	eval-logloss:0.15599
# [153]	train-logloss:0.13908	eval-logloss:0.15592
# [154]	train-logloss:0.13883	eval-logloss:0.15582
# [155]	train-logloss:0.13873	eval-logloss:0.15577
# [156]	train-logloss:0.13855	eval-logloss:0.15577
# [157]	train-logloss:0.13846	eval-logloss:0.15578
# [158]	train-logloss:0.13826	eval-logloss:0.15573
# [159]	train-logloss:0.13813	eval-logloss:0.15567
# [160]	train-logloss:0.13797	eval-logloss:0.15564
# [161]	train-logloss:0.13790	eval-logloss:0.15562
# [162]	train-logloss:0.13779	eval-logloss:0.15561
# [163]	train-logloss:0.13765	eval-logloss:0.15557
# [164]	train-logloss:0.13762	eval-logloss:0.15557
# [165]	train-logloss:0.13753	eval-logloss:0.15560
# [166]	train-logloss:0.13736	eval-logloss:0.15553
# [167]	train-logloss:0.13708	eval-logloss:0.15546
# [168]	train-logloss:0.13692	eval-logloss:0.15549
# [169]	train-logloss:0.13676	eval-logloss:0.15544
# [170]	train-logloss:0.13668	eval-logloss:0.15546
# [171]	train-logloss:0.13653	eval-logloss:0.15541
# [172]	train-logloss:0.13650	eval-logloss:0.15542
# [173]	train-logloss:0.13635	eval-logloss:0.15541
# [174]	train-logloss:0.13624	eval-logloss:0.15542
# [175]	train-logloss:0.13600	eval-logloss:0.15535
# [176]	train-logloss:0.13595	eval-logloss:0.15535
# [177]	train-logloss:0.13590	eval-logloss:0.15536
# [178]	train-logloss:0.13573	eval-logloss:0.15535
# [179]	train-logloss:0.13570	eval-logloss:0.15531
# [180]	train-logloss:0.13560	eval-logloss:0.15531
# [181]	train-logloss:0.13548	eval-logloss:0.15535
# [182]	train-logloss:0.13528	eval-logloss:0.15532
# [183]	train-logloss:0.13525	eval-logloss:0.15533
# [184]	train-logloss:0.13509	eval-logloss:0.15536
# [185]	train-logloss:0.13498	eval-logloss:0.15537
# [186]	train-logloss:0.13485	eval-logloss:0.15543
# [187]	train-logloss:0.13474	eval-logloss:0.15547
# [188]	train-logloss:0.13461	eval-logloss:0.15549
# [189]	train-logloss:0.13457	eval-logloss:0.15547

# %%
# predict on test data
test = pd.read_csv('data/test.csv')
test['person_home_ownership'] = test['person_home_ownership'].map({'RENT': 0, 'MORTGAGE': 1, 'OWN': 2, 'OTHER': 3})
test['loan_intent'] = test['loan_intent'].map({'PERSONAL': 0, 'EDUCATION': 1, 'MEDICAL': 2, 'VENTURE': 3, 'HOME': 4})
test['loan_grade'] = test['loan_grade'].map({'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5})
test['cb_person_default_on_file'] = test['cb_person_default_on_file'].map({'Y': 1, 'N': 0})

predicitions = model.predict(xgb.DMatrix(test.drop('id', axis=1)))
predicitions = [1.0 if x > 0.5 else 0.0 for x in predicitions]

# write predictions to file
output = pd.DataFrame({'id': test['id'], 'loan_status': predicitions})
output.to_csv('predictions.csv', index=False)
